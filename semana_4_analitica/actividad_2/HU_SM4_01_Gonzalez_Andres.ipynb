# %%
import pandas as pd

df = pd.read_csv('student-mat.csv', sep=';')



df_columns = df [["age","studytime","failures","absences","G1","G2","G3"]]
display(df_columns.head())


df_mayores = df_columns["age"] > 18
display(df_columns[df_mayores])

df_ausencias = df_columns["absences"] > 20
display(df_columns[df_ausencias])
# Out:
#    age  studytime  failures  absences  G1  G2  G3
# 0   18          2         0         6   5   6   6
# 1   17          2         0         4   5   5   6
# 2   15          2         3        10   7   8  10
# 3   15          3         0         2  15  14  15
# 4   16          2         0         4   6  10  10
#      age  studytime  failures  absences  G1  G2  G3
# 127   19          2         3         2   7   8   9
# 153   19          1         3         0   5   0   0
# 210   19          4         0        10   8   8   8
# 247   22          1         3        16   6   8   8
# 257   19          2         0        12  11  11  11
# 270   19          2         2        15   9   9   9
# 296   19          2         0         0  10   9   0
# 304   19          2         1        20  15  14  13
# 306   20          1         0         0  17  18  18
# 307   19          1         1        38   8   9   8
# 308   19          2         1         0  15  12  12
# ...
